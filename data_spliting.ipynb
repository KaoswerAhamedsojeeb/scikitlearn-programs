# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("car_data.csv")

# %%
df.head()
# Out:
#    mileage  age  price
# 0    15000    2  25000
# 1    22000    3  23000
# 2    18000    1  27000
# 3    30000    4  21000
# 4    12000    1  28000

# %%
sns.scatterplot(data = df, x="price", y= "mileage")
plt.show()

# %%
sns.scatterplot(data = df, x="age", y= "mileage")
plt.show()

# %%
x= df[["mileage", "age"]]
y=df["price"]

# %%
x
# Out:
#     mileage  age
# 0     15000    2
# 1     22000    3
# 2     18000    1
# 3     30000    4
# 4     12000    1
# ..      ...  ...
# 94    28000    3
# 95    39000    5
# 96    18000    2
# 97    31000    4
# 98    15000    1
#
# [99 rows x 2 columns]

# %%
y
# Out:
# 0     25000
# 1     23000
# 2     27000
# 3     21000
# 4     28000
#       ...
# 94    22100
# 95    19200
# 96    25100
# 97    20100
# 98    28100
# Name: price, Length: 99, dtype: int64

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y,train_size=(0.8), test_size=(0.2))

# %%
reg_model = LinearRegression()

# %%
reg_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg_model.predict(pd.DataFrame([{"mileage": 30000, "age": 4}]))
# Out:
# array([21105.21733809])

# %%
reg_model.score(x_test,ytes)
